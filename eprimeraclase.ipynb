# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciadn/Ejercicospython/blob/main/eprimeraclase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1
c="hola mundo"
print(a,c)
# Out:
# 1 hola mundo

# %%
x = str(3)    # x es un str
y = int(3)    # y es un entero
z = float(3)  # z es un flotante
print(x,y,z)

print(type(x),type(y),type(z))
# Out:
# 3 3 3.0
# <class 'str'> <class 'int'> <class 'float'>

# %%
x = "Iván"#cadenas
y = 'Iván'
print(x,y)
# Out:
# Iván Iván

# %%
a = 4
A = "Sally"
print(a,A)
# Out:
# 4 Sally

# %%
x,y,z="manzana", "pera", "mango"
print(x)
print(y)
print(z)
# Out:
# manzana
# pera
# mango

# %%
#calcular el área de un triángulo
#area (a), base(b), altura(h)
b=15 #base
h=20 #altura
a=b*h/2 #formula para calcular el área
print("El área del triángulo es: ",a," unidades cuadradas.")#imprimo resultado
# Out:
# El área del triángulo es:  150.0  unidades cuadradas.

# %%
suma=12+40
suma
# Out:
# 52

# %%
resta=79-23
resta
# Out:
# 56

# %%
mult=15*2
mult
# Out:
# 30

# %%
25**(1/2)
# Out:
# 5.0

# %%
divide=567/23
divide
# Out:
# 24.652173913043477

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
#comlejos
comp=2+3j
print(comp, type(comp))
# Out:
# (2+3j) <class 'complex'>

# %%
#c=celsius
C=25
F=(C*9/5)+32 # Celsius a Fahrenheit
print("La temperatura en Fahrenheit es: ",F)
k=C+273.15 #Celsius a Kelvin
print("La temperatura en Kelvin es: ",k)
R=(C+273.15)*9/5 #Celsius a Rankie
print("La temperatura en Rankine es: ",R)
# Out:
# La temperatura en Fahrenheit es:  77.0
# La temperatura en Kelvin es:  298.15
# La temperatura en Rankine es:  536.67
