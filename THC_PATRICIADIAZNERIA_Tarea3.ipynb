# %% [markdown]
# <a href="https://colab.research.google.com/github/patriciadn/Ejercicospython/blob/main/THC_PATRICIADIAZNERIA_Tarea3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.- Diseña un programa que convierta dólares americanos a pesos mexicanos, euros, libras esterlinas, yuanes y rublos utilizando una tasa de cambio fija. Muestre la tasa de cambio e imprima los cinco resultados.

# %%
#Tasas de cambio fijas
dolar_pesos=18.43
dolar_euros=0.85
dolar_libras=0.74
dolar_yuanes=7.12
dolar_rublos=81.50
Dólares_americanos=int(input("Ingrese la cantidad de dólares que desea convertir:"))
Pesos_mexicanos= Dólares_americanos*dolar_pesos
print("La conversión de dólares a pesos mexicanos son:",Pesos_mexicanos,"Pesos mexicanos")
Euros=Dólares_americanos*dolar_euros
print("La conversión de dólares a euros son:",Euros,"Euros")
Libras_Esterlinas=Dólares_americanos*dolar_libras
print("La conversión de dólares a libras esterlinas son:",Libras_Esterlinas,"Libras Esterlinas")
Yuanes=Dólares_americanos*dolar_yuanes
print("La conversión de dólares a yuanes son:",Yuanes,"Yuanes")
Rublos=Dólares_americanos*dolar_rublos
print("La conversión de dólares a rublos son:",Rublos,"Rublos")
# Out:
# Ingrese la cantidad de dólares que desea convertir:50
# La conversión de dólares a pesos mexicanos son: 921.5 Pesos mexicanos
# La conversión de dólares a euros son: 42.5 Euros
# La conversión de dólares a libras esterlinas son: 37.0 Libras Esterlinas
# La conversión de dólares a yuanes son: 356.0 Yuanes
# La conversión de dólares a rublos son: 4075.0 Rublos

# %% [markdown]
# 2.- Crea un programa que solicite al usuario dos números y realice las operaciones básicas como suma, resta, multiplicación, división, potenciación y raíz cuadrada. Muestra los resultados usando variables.

# %%
a=int(input("Ingrese el primer número:"))
b=int(input("Ingrese el segundo número:"))
suma=a+b
print("La suma de los números es:",suma)
resta=a-b
print("La resta de los números es:",resta)
multiplicacion=a*b
print("La multiplicación de los números es:",multiplicacion)
division=a/b
print("La división de los números es:",division)
potenciacion=a**b
print("La potenciación de los números es:",potenciacion)
raiz_cuadrada=a**0.5
raiz_cuadrada2=b**0.5
print("La raíz cuadrada del primer número es:",raiz_cuadrada)
print("La raíz cuadrada del segundo número es:",raiz_cuadrada2)
# Out:
# Ingrese el primer número:5
# Ingrese el segundo número:3
# La suma de los números es: 8
# La resta de los números es: 2
# La multiplicación de los números es: 15
# La división de los números es: 1.6666666666666667
# La potenciación de los números es: 125
# La raíz cuadrada del primer número es: 2.23606797749979
# La raíz cuadrada del segundo número es: 1.7320508075688772

# %% [markdown]
# 3.- Desarrolla un programa que calcule el precio final de un producto después de aplicar un descuento. El usuario debe ingresar el precio original y el porcentaje de descuento. Utiliza variables para almacenar los valores.

# %%
Precio_original=int(input("Ingrese el precio original del producto:"))
Descuento=int(input("Ingrese el porcentaje de descuento:"))
Precio_final=Precio_original-(Precio_original*Descuento/100)
print("El precio final del producto es:",Precio_final,"pesos")
# Out:
# Ingrese el precio original del producto:400
# Ingrese el porcentaje de descuento:20
# El precio final del producto es: 320.0

# %% [markdown]
# 4.- Conversión de coordenadas y localización geográfica.
#
# Para cada uno de los siguientes pares de coordenadas (latitud, longitud), realiza lo siguiente usando solo variables (sin funciones definidas por ti, sin ciclos):
#
# a).- Guarda los valores de grados, minutos y segundos en variables separadas (por latitud y por longitud).
#
# b).- Convierte cada coordenada a grados decimales mediante la fórmula:
#
# \begin{equation} \text{decimal} = \text{grados} + \frac{\text{minutos}}{60} + \frac{\text{segundos}}{3600} \end{equation}
#
# Imprime la latitud y longitud con su valor decimal. Redondee los valores a 3 decimales (si aplica).
#
# Busca en la literatura (o en línea) qué lugar emblemático corresponde aproximadamente a esas coordenadas.
#
# Coordenadas a utilizar:
#
# $$ \begin{array}{|c|c|c|} \hline \# & Latitud (° , ' , ") & Longitud (° , ' , ") \\ \hline 1 & 40° 41′ 21″ N & 74° 2′ 40″ W \\ 2 & 48° 51′ 12″ N & 2° 20′ 55″ E \\ 3 & 34° 3′ 8″ S & 151° 12′ 33″ E \\ \hline \end{array} $$
#
# Recomendaciones:
#
# Si es latitud Norte o Sur, coloca el signo adecuado (positivo para Norte, negativo para Sur).
#
# Si es longitud Este u Oeste, también aplica signo (+ para Este, − para oeste).
#
# Consulta fuentes confiables para identificar los lugares.
#
# Es suficiente dar una aproximación (puede no ser exacta), con nombre de ciudad o monumento cercano.

# %%
#Latitud
Lat1=40
Min1=41
Seg1=21
Lat_hemisferio1="N"
Lat2=48
Min2=51
Seg2=12
Lat_hemisferio2="N"
Lat3=34
Min3=3
Seg3=8
Lat_hemisferio3="S"
#Longitud
Lon1=74
Min2=2
Seg2=40
Lon_hemisferio1="W"
Lon2=2
Min2=20
Seg2=55
Lon_hemisferio2="E"
Lon3=151
Min3=12
Seg3=33
Lon_hemisferio3="E"
# Convertir cada coordenada a grados decimales mediante la fórmula:
decimal1=Lat1+Min1/60+Seg1/3600
decimal2=Lat2+Min2/60+Seg2/3600
decimal3=Lat3+Min3/60+Seg3/3600
decimal4=Lon1+Min2/60+Seg2/3600
decimal5=Lon2+Min2/60+Seg2/3600
decimal6=Lon3+Min3/60+Seg3/3600
#Si la latitud es N, +
#Si la latitud es S, -
#Si la longitud es E, +
#Si la longitud es W -
if Lat_hemisferio1=="N":
  decimal1=decimal1
else:
  decimal1=-decimal1

if Lat_hemisferio2=="N":
  decimal2=decimal2
else:
  decimal2=-decimal2

if Lat_hemisferio3=="N":
  decimal3=decimal3
else:
  decimal3=-decimal3

if Lon_hemisferio1=="E":
  decimal4=decimal4
else:
  decimal4=-decimal4

if Lon_hemisferio2=="E":
  decimal5=decimal5
else:
  decimal5=-decimal5

if Lon_hemisferio3=="E":
  decimal6=decimal6
else:
  decimal6=-decimal6

print("La latitud 1 es:",round(decimal1,3), Lat_hemisferio1)
print("La longitud 1 es:",round(decimal4,3),Lon_hemisferio1)
print("Este punto corresponde a la Estatua de la Libertad en la Isla de la Libertad en la ciudad de Nueva York.")
print("La latitud 2 es:",round(decimal2,3),Lat_hemisferio2)
print("La longitud 2 es:",round(decimal5,3),Lon_hemisferio2)
print("Este punto corresponde a París, Francia (Catedral de Notre Dame).")
print("La latitud 3 es:",round(decimal3,3),Lat_hemisferio3)
print("La longitud 3 es:",round(decimal6,3),Lon_hemisferio3)
print("Este punto corresponde a Kurnell, Nueva Gales del Sur, Australia.")
#Los lugares los saque al buscar las coordenadas en Google Earth
# Out:
# La latitud 1 es: 40.689 N
# La longitud 1 es: -74.349 W
# Este punto corresponde a la Estatua de la Libertad en la Isla de la Libertad en la ciudad de Nueva York.
# La latitud 2 es: 48.349 N
# La longitud 2 es: 2.349 E
# Este punto corresponde a París, Francia (Catedral de Notre Dame).
# La latitud 3 es: -34.209 S
# La longitud 3 es: 151.209 E
# Este punto corresponde a Kurnell, Nueva Gales del Sur, Australia.

# %% [markdown]
# 5.- Un objeto de masa m=2 kg se encuentra a una altura h=10 cm y tiene una velocidad de v=3 m/s. Calcular:
#
# a) La energía cinética (Ec),
#
# b) La energía potencial gravitacional (Ep),
#
# c) La energía mecánica total (Em).
#
# Considere g=9.8m/s^2. Revise las unidades.

# %%
m=2 #masa
h=0.1 #Altura metros= cm/100
v=3 #velocidad
Energía_cinética=0.5*m*(v**2)
Energía_potencial_gravitacional=m*9.8*h
Energía_mecánica_total=Energía_cinética+Energía_potencial_gravitacional
print("La energía cinética es:",Energía_cinética,"J")
print("La energía potencial gravitacional es:",Energía_potencial_gravitacional,"J")
print("La energía mecánica total es:",Energía_mecánica_total,"J")
# Out:
# La energía cinética es: 9.0 J
# La energía potencial gravitacional es: 1.9600000000000002 J
# La energía mecánica total es: 10.96 J

# %% [markdown]
# 6.- Escribe un programa que pida un número entero y determine si es par o impar utilizando la sentencia if-elif-else. Si el valor ingresado no es un entero válido, el programa debe indicarlo y que vuelva a ejecutar el programa.
#
# Hint. Recuerde la operación módulo.

# %%
#Si el número es par el residuo siempre es 0
#Si el número es impar, el residuo siempre es 1
  a=int(input("Ingrese un número entero:"))
  if a%2==0:
    print("El número es par")
  else:
    print("El número es impar")
except ValueError:
  print("Entrada inválida. Por favor, ingrese un número entero.")
# Out:
# Ingrese un número entero:-100000000000000000
# El número es par

# %% [markdown]
# 7.- Tipo de triángulo.
#
# Solicite al usuario que ingrese los valores de los lados de un triángulo (enteros positivos) y realice lo siguiente:
#
# a).- Valide que formen un triángulo (desigualdad triangular).
#
# b).- Si forman un triángulo, indica si es equilátero, isosceles o escaleno.

# %%
a=int(input("Ingrese el primer lado del triángulo:"))
b=int(input("Ingrese el segundo lado del triángulo:"))
c=int(input("Ingrese el tercer lado del triángulo:"))
if a+b>c and a+c>b and b+c>a:
  print("El triángulo es válido")
  if a==b==c:
    print("El triángulo es equilátero")
  elif a==b or a==c or b==c:
    print("El triángulo es isósceles")
  else:
    print("El triángulo es escaleno")
else:
  print("El triángulo no es válido")
# Out:
# Ingrese el primer lado del triángulo:12
# Ingrese el segundo lado del triángulo:7
# Ingrese el tercer lado del triángulo:8
# El triángulo es válido
# El triángulo es escaleno

# %% [markdown]
# 8.- Crea un script en Python que determine cuál de tres números introducidos por el usuario es el mayor, usando sentencias IF anidadas o múltiples ELIF.

# %%
a=int(input("Ingrese el primer número:"))
b=int(input("Ingrese el segundo número:"))
c=int(input("Ingrese el tercer número:"))
if a>b and a>c:
  print("El primer número es el mayor")
elif b>a and b>c:
  print("El segundo número es el mayor")
elif c>a and c>b:
  print("El tercer número es el mayor")
elif a==b and a>c:
    print("El primer y el segundo número son los mayores")
elif b==c and b>a:
    print("El segundo y el tercer número son los mayores")
elif c==a and c>b:
    print("El tercer y el primer número son los mayores")
else:
  print("Los números son iguales")
# Out:
# Ingrese el primer número:12
# Ingrese el segundo número:4
# Ingrese el tercer número:7
# El primer número es el mayor

# %% [markdown]
# 9.- Programe un script en Python que determine si dos rectas dadas por las ecuaciones y1=m1x + b1 y y2=m2x+b2 se intersectan, son paralelas o coincidentes. Utilice estructuras de control (IF - ELSE) para manejar los diferentes casos.

# %%
m1 = float(input("Ingrese el valor de la pendiente 1 (m1): "))
b1 = float(input("Ingrese el valor de la intersección con el eje y 1 (b1): "))
m2 = float(input("Ingrese el valor de la pendiente 2 (m2): "))
b2 = float(input("Ingrese el valor de la intersección con el eje y 2 (b2): "))

if m1 == m2 and b1 == b2:
    print("Las rectas son coincidentes")
elif m1 == m2 and b1 != b2:
    print("Las rectas son paralelas")
elif m1 * m2 == -1:
  print("Las rectas son perpendiculares")
else:
    print("Las rectas se intersectan en un punto")
# Out:
# Ingrese el valor de la pendiente 1 (m1): 3
# Ingrese el valor de la intersección con el eje y 1 (b1): 5
# Ingrese el valor de la pendiente 2 (m2): 4
# Ingrese el valor de la intersección con el eje y 2 (b2): 5
# Las rectas se intersectan en un punto

# %% [markdown]
# 10.- Escriba un programa que solicite al usuario un año y que el programa indique si es bisiesto o no. Recuerde, los años bisiestos son múltiplos de 4, no es el caso para los múltiplos de 100, pero si para los múltiplos de 400.

# %%
a=int(input("Ingrese un año:"))
if (a%4==0 and a%100!=0) or (a%400==0):
  print("El año es bisiesto")
else:
  print("El año no es bisiesto")
# Out:
# Ingrese un año:2000
# El año es bisiesto
